# %% [markdown]
# Table 3 - Alcohol-related deaths1,2, by gender

# %%
from gssutils import *

if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://webarchive.nationalarchives.gov.uk/20180328130416/http://digital.nhs.uk/media/30889/Statistics-on-Alcohol-England-2017-Tables/Any/alc-eng-2017-tab'
    inputFile = sourceFolder / 'alc-eng-2017-tab'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='Table 3')[0]
# Out:
# Loading in\alc-eng-2017-tab which has size 126229 bytes
# Table names: ['Table 3']

# %%
observations = tab.excel_ref('E8').expand(DOWN).expand(RIGHT).is_not_blank()
observations
# Out:
# {<E11 9.0>, <G14 2.0>, <E18 7.0>, <G20 1.0>, <E21 4.0>, <E20 4.0>, <F18 7.0>, <E8 6813.0>, <F17 971.0>, <E19 313.0>, <G18 0.0>, <F16 2.0>, <F20 3.0>, <F11 6.0>, <E16 3.0>, <F21 3.0>, <G21 1.0>, <E14 8.0>, <G16 1.0>, <G12 0.0>, <G10 117.0>, <F13 62.0>, <F19 205.0>, <F10 288.0>, <E10 405.0>, <G17 602.0>, <G8 2382.0>, <F12 0.0>, <E15 4411.0>, <E17 1573.0>, <F14 6.0>, <G11 3.0>, <F15 2878.0>, <G19 108.0>, <G13 14.0>, <G15 1533.0>, <F8 4431.0>, <E12 0.0>, <E13 76.0>}

# %%
gr = tab.excel_ref('E6').expand(RIGHT).is_not_blank()
gr
# Out:
# {<F6 'Male'>, <E6 'All persons'>, <G6 'Female'>}

# %%
code = tab.excel_ref('C10').expand(DOWN).is_not_blank() 
code
# Out:
# {<C21 'Y15'>, <C15 'K70'>, <C10 'F10'>, <C17 'K74 (excluding K74.3 - K74.5, biliary cirrhosis)'>, <C19 'X45'>, <C11 'G31.2'>, <C14 'K29.2'>, <C12 'G62.1'>, <C16 'K73'>, <C20 'X65'>, <C13 'I42.6'>, <C18 'K86.0'>}

# %%
des = tab.excel_ref('A8').expand(DOWN).is_not_blank() - tab.excel_ref('A22')
des
# Out:
# {<A26 2.0>, <A17 'Fibrosis and cirrhosis of liver'>, <A25 1.0>, <A20 'Intentional self-poisoning by and exposure to alcohol'>, <A35 'Copyright © 2017. The Health and Social Care Information Centre, Lifestyles Statistics. All rights reserved.'>, <A8 'Total'>, <A24 'Footnotes'>, <A12 'Alcoholic polyneuropathy'>, <A31 'Alcohol-related deaths by sex, age group and individual cause of death, UK constituent countries, deaths registered 2001 to 2015 - Office for National Statistics'>, <A34 'Copyright © 2017, re-used with the permission of The Office for National Statistics.'>, <A27 3.0>, <A21 'Poisoning by and exposure to alcohol, undetermined intent'>, <A16 'Chronic hepatitis, not elsewhere classified'>, <A18 'Alcohol induced chronic pancreatitis'>, <A11 'Degeneration of nervous system due to alcohol'>, <A13 'Alcoholic cardiomyopathy'>, <A15 'Alcoholic liver disease'>, <A30 'Source'>, <A10 'Mental and behavioural disorders due to use of alcohol'>, <A32 'http://www.ons.gov.uk/peoplepopulationandcommunity/healthandsocialcare/causesofdeath/datasets/alcoholrelateddeathsbysexagegroupandindividualcauseofdeath'>, <A19 'Accidental poisoning by and exposure to alcohol'>, <A14 'Alcoholic gastritis'>}

# %%
Dimensions = [
            HDimConst('Category','Alcohol related deaths'),
            HDim(code,'ICD-10 Code',DIRECTLY,LEFT),
            HDim(gr,'Sex',DIRECTLY,ABOVE),
            HDimConst('Geography','E92000001'),
            HDimConst('Period','2015'),
            HDimConst('Unit','People'),
            HDimConst('Measure Type','Count'),
            HDim(des,'ICD-10 Description',DIRECTLY,LEFT)     
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS                Category  \
# 0   6813.0  Alcohol related deaths
# 1   4431.0  Alcohol related deaths
# 2   2382.0  Alcohol related deaths
# 3    405.0  Alcohol related deaths
# 4    288.0  Alcohol related deaths
# 5    117.0  Alcohol related deaths
# 6      9.0  Alcohol related deaths
# 7      6.0  Alcohol related deaths
# 8      3.0  Alcohol related deaths
# 9      0.0  Alcohol related deaths
# 10     0.0  Alcohol related deaths
# 11     0.0  Alcohol related deaths
# 12    76.0  Alcohol related deaths
# 13    62.0  Alcohol related deaths
# 14    14.0  Alcohol related deaths
# 15     8.0  Alcohol related deaths
# 16     6.0  Alcohol related deaths
# 17     2.0  Alcohol related deaths
# 18  4411.0  Alcohol related deaths
# 19  2878.0  Alcohol related deaths
# 20  1533.0  Alcohol related deaths
# 21     3.0  Alcohol related deaths
# 22     2.0  Alcohol related deaths
# 23     1.0  Alcohol related deaths
# 24  1573.0  Alcohol related deaths
# 25   971.0  Alcohol related deaths
# 26   602.0  Alcohol related deaths
# 27     7.0  Alcohol related deaths
# 28     7.0  Alcohol related deaths
# 29     0.0  Alcohol related deaths
# 30   313.0  Alcohol related deaths
# 31   205.0  Alcohol related deaths
# 32   108.0  Alcohol related deaths
# 33     4.0  Alcohol related deaths
# 34     3.0  Alcohol related deaths
# 35     1.0  Alcohol related deaths
# 36     4.0  Alcohol related deaths
# 37     3.0  Alcohol related deaths
# 38     1.0  Alcohol related deaths
#
# 6       Degeneration of nervous system due to alcohol
# 7       Degeneration of nervous system due to alcohol
# 8       Degeneration of nervous system due to alcohol
# 9                            Alcoholic polyneuropathy
# 10                           Alcoholic polyneuropathy
# 11                           Alcoholic polyneuropathy
# 12                           Alcoholic cardiomyopathy
# 13                           Alcoholic cardiomyopathy
# 14                           Alcoholic cardiomyopathy
# 15                                Alcoholic gastritis
# 16                                Alcoholic gastritis
# 17                                Alcoholic gastritis
# 18                            Alcoholic liver disease
# 19                            Alcoholic liver disease
# 20                            Alcoholic liver disease
# 21        Chronic hepatitis, not elsewhere classified
# 22        Chronic hepatitis, not elsewhere classified
# 23        Chronic hepatitis, not elsewhere classified
# 24                    Fibrosis and cirrhosis of liver
# 25                    Fibrosis and cirrhosis of liver
# 26                    Fibrosis and cirrhosis of liver
# 27               Alcohol induced chronic pancreatitis
# 28               Alcohol induced chronic pancreatitis
# 29               Alcohol induced chronic pancreatitis
# 30    Accidental poisoning by and exposure to alcohol
# 31    Accidental poisoning by and exposure to alcohol
# 32    Accidental poisoning by and exposure to alcohol
# 33  Intentional self-poisoning by and exposure to ...
# 34  Intentional self-poisoning by and exposure to ...
# 35  Intentional self-poisoning by and exposure to ...
# 36  Poisoning by and exposure to alcohol, undeterm...
# 37  Poisoning by and exposure to alcohol, undeterm...
# 38  Poisoning by and exposure to alcohol, undeterm...

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.head()
# Out:
#     Value                Category ICD-10 Code          Sex  Geography Period  \
# 0  6813.0  Alcohol related deaths        None  All persons  E92000001   2015
# 1  4431.0  Alcohol related deaths        None         Male  E92000001   2015
# 2  2382.0  Alcohol related deaths        None       Female  E92000001   2015
# 3   405.0  Alcohol related deaths         F10  All persons  E92000001   2015
# 4   288.0  Alcohol related deaths         F10         Male  E92000001   2015
#
#      Unit Measure Type                                 ICD-10 Description
# 0  People        Count                                              Total
# 1  People        Count                                              Total
# 2  People        Count                                              Total
# 3  People        Count  Mental and behavioural disorders due to use of...
# 4  People        Count  Mental and behavioural disorders due to use of...

# %%
new_table['ICD-10 Description'] = new_table['ICD-10 Description'].map(
    lambda x: {
        'Total' : 'All deaths' 
        }.get(x, x))

# %%
new_table.head()
# Out:
#     Value                Category ICD-10 Code          Sex  Geography Period  \
# 0  6813.0  Alcohol related deaths        None  All persons  E92000001   2015
# 1  4431.0  Alcohol related deaths        None         Male  E92000001   2015
# 2  2382.0  Alcohol related deaths        None       Female  E92000001   2015
# 3   405.0  Alcohol related deaths         F10  All persons  E92000001   2015
# 4   288.0  Alcohol related deaths         F10         Male  E92000001   2015
#
#      Unit Measure Type                                 ICD-10 Description
# 0  People        Count                                         All deaths
# 1  People        Count                                         All deaths
# 2  People        Count                                         All deaths
# 3  People        Count  Mental and behavioural disorders due to use of...
# 4  People        Count  Mental and behavioural disorders due to use of...

# %%
new_table.tail()
# Out:
#     Value                Category ICD-10 Code          Sex  Geography Period  \
# 34    3.0  Alcohol related deaths         X65         Male  E92000001   2015
# 35    1.0  Alcohol related deaths         X65       Female  E92000001   2015
# 36    4.0  Alcohol related deaths         Y15  All persons  E92000001   2015
# 37    3.0  Alcohol related deaths         Y15         Male  E92000001   2015
# 38    1.0  Alcohol related deaths         Y15       Female  E92000001   2015
#
#       Unit Measure Type                                 ICD-10 Description
# 34  People        Count  Intentional self-poisoning by and exposure to ...
# 35  People        Count  Intentional self-poisoning by and exposure to ...
# 36  People        Count  Poisoning by and exposure to alcohol, undeterm...
# 37  People        Count  Poisoning by and exposure to alcohol, undeterm...
# 38  People        Count  Poisoning by and exposure to alcohol, undeterm...

# %%
new_table.dtypes
# Out:
# Value                 float64
# Category               object
# ICD-10 Code            object
# Sex                    object
# Geography              object
# Period                 object
# Unit                   object
# Measure Type           object
# ICD-10 Description     object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(int)

# %%
new_table['Period'] = new_table['Period'].astype(int)

# %%
new_table.head(3)
# Out:
#    Value                Category ICD-10 Code          Sex  Geography  Period  \
# 0   6813  Alcohol related deaths        None  All persons  E92000001    2015
# 1   4431  Alcohol related deaths        None         Male  E92000001    2015
# 2   2382  Alcohol related deaths        None       Female  E92000001    2015
#
#      Unit Measure Type ICD-10 Description
# 0  People        Count         All deaths
# 1  People        Count         All deaths
# 2  People        Count         All deaths

# %%
new_table['Sex'] = new_table['Sex'].map(
    lambda x: {
        'Female' : 'F', 
        'Male' : 'M',
        'All persons' : 'T'
        }.get(x, x))

# %%
new_table['ICD-10 Code'].fillna('All', inplace = True)

# %%
new_table = new_table[['Geography','Period','Sex','Category','ICD-10 Code','ICD-10 Description','Measure Type','Value','Unit']]

# %%
if is_interactive():
    SubstancetinationFolder = Path('out')
    SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(SubstancetinationFolder / ('table3.csv'), index = False)

# %%
new_table.head()
# Out:
#    Geography  Period                Category ICD-10 Code  \
# 0  E92000001    2015  Alcohol related deaths         All
# 1  E92000001    2015  Alcohol related deaths         All
# 2  E92000001    2015  Alcohol related deaths         All
# 3  E92000001    2015  Alcohol related deaths         F10
# 4  E92000001    2015  Alcohol related deaths         F10
#
#                                   ICD-10 Description Measure Type  Value  \
# 0                                         All deaths        Count   6813
# 1                                         All deaths        Count   4431
# 2                                         All deaths        Count   2382
# 3  Mental and behavioural disorders due to use of...        Count    405
# 4  Mental and behavioural disorders due to use of...        Count    288
#
#      Unit
# 0  People
# 1  People
# 2  People
# 3  People
# 4  People
